# %%
# dataset @ https://finance.yahoo.com/quote/MSFT/history/

# %%
import pandas as pd

df = pd.read_csv('/content/MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060980
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063158
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064247
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062613
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061524
# ...          ...         ...         ...         ...         ...         ...
# 9234  2022-10-31  233.759995  234.919998  231.149994  232.130005  232.130005
# 9235  2022-11-01  234.600006  235.740005  227.330002  228.169998  228.169998
# 9236  2022-11-02  229.460007  231.300003  220.039993  220.100006  220.100006
# 9237  2022-11-03  220.089996  220.410004  213.979996  214.250000  214.250000
# 9238  2022-11-04  217.550003  221.589996  213.429993  221.389999  221.389999
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9234    28357300
# 9235    30592300
# 9236    38407000
# 9237    36633900
# 9238    36767800
#
# [9239 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9234  2022-10-31  232.130005
# 9235  2022-11-01  228.169998
# 9236  2022-11-02  220.100006
# 9237  2022-11-03  214.250000
# 9238  2022-11-04  221.389999
#
# [9239 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9234    2022-10-31
# 9235    2022-11-01
# 9236    2022-11-02
# 9237    2022-11-03
# 9238    2022-11-04
# Name: Date, Length: 9239, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9234  2022-10-31  232.130005
# 9235  2022-11-01  228.169998
# 9236  2022-11-02  220.100006
# 9237  2022-11-03  214.250000
# 9238  2022-11-04  221.389999
#
# [9239 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9234   2022-10-31
# 9235   2022-11-01
# 9236   2022-11-02
# 9237   2022-11-03
# 9238   2022-11-04
# Name: Date, Length: 9239, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2022-10-31  232.130005
# 2022-11-01  228.169998
# 2022-11-02  220.100006
# 2022-11-03  214.250000
# 2022-11-04  221.389999
#
# [9239 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 4s 116ms/step - loss: 84881.8906 - mean_absolute_error: 289.6051 - val_loss: 92584.8672 - val_mean_absolute_error: 304.1906
# Epoch 2/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84653.1562 - mean_absolute_error: 289.2119 - val_loss: 92364.4219 - val_mean_absolute_error: 303.8280
# Epoch 3/100
# 7/7 [==============================] - 0s 9ms/step - loss: 84437.7344 - mean_absolute_error: 288.8376 - val_loss: 92112.8438 - val_mean_absolute_error: 303.4137
# Epoch 4/100
# 7/7 [==============================] - 0s 9ms/step - loss: 84174.3594 - mean_absolute_error: 288.3841 - val_loss: 91812.7422 - val_mean_absolute_error: 302.9188
# Epoch 5/100
# 7/7 [==============================] - 0s 10ms/step - loss: 83879.2500 - mean_absolute_error: 287.8685 - val_loss: 91460.4688 - val_mean_absolute_error: 302.3367
# Epoch 6/100
# 7/7 [==============================] - 0s 12ms/step - loss: 83506.1094 - mean_absolute_error: 287.2198 - val_loss: 91022.5391 - val_mean_absolute_error: 301.6116
# Epoch 7/100
# 7/7 [==============================] - 0s 13ms/step - loss: 83068.5625 - mean_absolute_error: 286.4563 - val_loss: 90505.1719 - val_mean_absolute_error: 300.7527
# Epoch 8/100
# 7/7 [==============================] - 0s 10ms/step - loss: 82530.3750 - mean_absolute_error: 285.5171 - val_loss: 89840.4688 - val_mean_absolute_error: 299.6456
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 81810.1016 - mean_absolute_error: 284.2543 - val_loss: 88969.2031 - val_mean_absolute_error: 298.1882
# Epoch 10/100
# 7/7 [==============================] - 0s 9ms/step - loss: 80947.9844 - mean_absolute_error: 282.7318 - val_loss: 87950.6094 - val_mean_absolute_error: 296.4753
# Epoch 11/100
# 7/7 [==============================] - 0s 9ms/step - loss: 79830.8203 - mean_absolute_error: 280.7472 - val_loss: 86588.3828 - val_mean_absolute_error: 294.1690
# Epoch 12/100
# 7/7 [==============================] - 0s 10ms/step - loss: 78508.7031 - mean_absolute_error: 278.3801 - val_loss: 84968.0703 - val_mean_absolute_error: 291.4017
# Epoch 13/100
# 7/7 [==============================] - 0s 10ms/step - loss: 76708.5156 - mean_absolute_error: 275.1194 - val_loss: 82859.0078 - val_mean_absolute_error: 287.7604
# Epoch 14/100
# 7/7 [==============================] - 0s 9ms/step - loss: 74753.7188 - mean_absolute_error: 271.5598 - val_loss: 80675.5312 - val_mean_absolute_error: 283.9411
# Epoch 15/100
# 7/7 [==============================] - 0s 10ms/step - loss: 72526.6484 - mean_absolute_error: 267.4185 - val_loss: 78172.4688 - val_mean_absolute_error: 279.4986
# Epoch 16/100
# 7/7 [==============================] - 0s 9ms/step - loss: 70049.9688 - mean_absolute_error: 262.7362 - val_loss: 75257.2578 - val_mean_absolute_error: 274.2338
# Epoch 17/100
# 7/7 [==============================] - 0s 10ms/step - loss: 66973.5156 - mean_absolute_error: 256.8295 - val_loss: 71544.9609 - val_mean_absolute_error: 267.3799
# Epoch 18/100
# 7/7 [==============================] - 0s 9ms/step - loss: 63516.7109 - mean_absolute_error: 249.9896 - val_loss: 67937.6562 - val_mean_absolute_error: 260.5469
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 59933.7344 - mean_absolute_error: 242.7282 - val_loss: 63601.3203 - val_mean_absolute_error: 252.0876
# Epoch 20/100
# 7/7 [==============================] - 0s 10ms/step - loss: 55478.4336 - mean_absolute_error: 233.3839 - val_loss: 58675.4336 - val_mean_absolute_error: 242.1208
# Epoch 21/100
# 7/7 [==============================] - 0s 11ms/step - loss: 50919.2734 - mean_absolute_error: 223.3640 - val_loss: 53575.7500 - val_mean_absolute_error: 231.3496
# Epoch 22/100
# 7/7 [==============================] - 0s 9ms/step - loss: 45948.2227 - mean_absolute_error: 211.9500 - val_loss: 48179.3203 - val_mean_absolute_error: 219.3772
# Epoch 23/100
# 7/7 [==============================] - 0s 10ms/step - loss: 40959.9844 - mean_absolute_error: 199.8692 - val_loss: 42830.1562 - val_mean_absolute_error: 206.8264
# Epoch 24/100
# 7/7 [==============================] - 0s 9ms/step - loss: 35922.9141 - mean_absolute_error: 186.7505 - val_loss: 37293.0469 - val_mean_absolute_error: 192.9769
# Epoch 25/100
# 7/7 [==============================] - 0s 9ms/step - loss: 30859.8125 - mean_absolute_error: 172.7531 - val_loss: 31955.6426 - val_mean_absolute_error: 178.6132
# Epoch 26/100
# 7/7 [==============================] - 0s 8ms/step - loss: 26013.4883 - mean_absolute_error: 158.1025 - val_loss: 26798.5020 - val_mean_absolute_error: 163.5406
# Epoch 27/100
# 7/7 [==============================] - 0s 8ms/step - loss: 21426.0176 - mean_absolute_error: 142.8293 - val_loss: 21950.4434 - val_mean_absolute_error: 147.9780
# Epoch 28/100
# 7/7 [==============================] - 0s 8ms/step - loss: 17200.0371 - mean_absolute_error: 127.1290 - val_loss: 17488.1348 - val_mean_absolute_error: 132.0417
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 13302.7910 - mean_absolute_error: 110.6870 - val_loss: 13281.6514 - val_mean_absolute_error: 115.0144
# Epoch 30/100
# 7/7 [==============================] - 0s 8ms/step - loss: 9801.2881 - mean_absolute_error: 93.5998 - val_loss: 9774.4629 - val_mean_absolute_error: 98.5977
# Epoch 31/100
# 7/7 [==============================] - 0s 10ms/step - loss: 7131.7720 - mean_absolute_error: 78.0732 - val_loss: 7079.9746 - val_mean_absolute_error: 83.8272
# Epoch 32/100
# 7/7 [==============================] - 0s 11ms/step - loss: 5104.6978 - mean_absolute_error: 63.6451 - val_loss: 4959.3384 - val_mean_absolute_error: 70.0455
# Epoch 33/100
# 7/7 [==============================] - 0s 8ms/step - loss: 3569.4541 - mean_absolute_error: 50.5742 - val_loss: 3370.6543 - val_mean_absolute_error: 57.5994
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2492.8430 - mean_absolute_error: 40.3427 - val_loss: 2245.9111 - val_mean_absolute_error: 46.8289
# Epoch 35/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1830.1968 - mean_absolute_error: 34.7648 - val_loss: 1477.9893 - val_mean_absolute_error: 37.7495
# Epoch 36/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1435.0040 - mean_absolute_error: 31.6353 - val_loss: 979.8036 - val_mean_absolute_error: 30.4440
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1201.7170 - mean_absolute_error: 29.3325 - val_loss: 683.2960 - val_mean_absolute_error: 25.1064
# Epoch 38/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1087.0403 - mean_absolute_error: 27.9423 - val_loss: 497.6621 - val_mean_absolute_error: 21.0878
# Epoch 39/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1039.8395 - mean_absolute_error: 27.2679 - val_loss: 381.3594 - val_mean_absolute_error: 18.1216
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1015.7927 - mean_absolute_error: 26.9433 - val_loss: 320.3335 - val_mean_absolute_error: 16.3514
# Epoch 41/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1011.1627 - mean_absolute_error: 26.8520 - val_loss: 281.2040 - val_mean_absolute_error: 15.1568
# Epoch 42/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.0786 - mean_absolute_error: 26.8621 - val_loss: 262.7652 - val_mean_absolute_error: 14.5835
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.4526 - mean_absolute_error: 26.8724 - val_loss: 257.5854 - val_mean_absolute_error: 14.4180
# Epoch 44/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.3276 - mean_absolute_error: 26.8683 - val_loss: 265.6110 - val_mean_absolute_error: 14.6736
# Epoch 45/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.1389 - mean_absolute_error: 26.8614 - val_loss: 263.4071 - val_mean_absolute_error: 14.6039
# Epoch 46/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.1434 - mean_absolute_error: 26.8640 - val_loss: 260.5150 - val_mean_absolute_error: 14.5119
# Epoch 47/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.1920 - mean_absolute_error: 26.8651 - val_loss: 259.1550 - val_mean_absolute_error: 14.4684
# Epoch 48/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.2941 - mean_absolute_error: 26.8653 - val_loss: 261.8151 - val_mean_absolute_error: 14.5533
# Epoch 49/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1010.3362 - mean_absolute_error: 26.8645 - val_loss: 268.7690 - val_mean_absolute_error: 14.7728
# Epoch 50/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.3267 - mean_absolute_error: 26.8657 - val_loss: 274.1243 - val_mean_absolute_error: 14.9395
# Epoch 51/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1009.8901 - mean_absolute_error: 26.8559 - val_loss: 276.4484 - val_mean_absolute_error: 15.0112
# Epoch 52/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.9685 - mean_absolute_error: 26.8719 - val_loss: 272.8347 - val_mean_absolute_error: 14.8996
# Epoch 53/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1009.8904 - mean_absolute_error: 26.8593 - val_loss: 278.8704 - val_mean_absolute_error: 15.0855
# Epoch 54/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.5218 - mean_absolute_error: 26.8647 - val_loss: 281.3952 - val_mean_absolute_error: 15.1626
# Epoch 55/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1009.8170 - mean_absolute_error: 26.8575 - val_loss: 273.0179 - val_mean_absolute_error: 14.9053
# Epoch 56/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1009.9529 - mean_absolute_error: 26.8565 - val_loss: 273.0617 - val_mean_absolute_error: 14.9066
# Epoch 57/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1009.7069 - mean_absolute_error: 26.8546 - val_loss: 268.5232 - val_mean_absolute_error: 14.7653
# Epoch 58/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1006.6198 - mean_absolute_error: 26.8097 - val_loss: 286.5530 - val_mean_absolute_error: 15.3329
# Epoch 59/100
# 7/7 [==============================] - 0s 8ms/step - loss: 985.0674 - mean_absolute_error: 26.4663 - val_loss: 302.8591 - val_mean_absolute_error: 15.8516
# Epoch 60/100
# 7/7 [==============================] - 0s 8ms/step - loss: 975.9608 - mean_absolute_error: 26.4274 - val_loss: 302.2561 - val_mean_absolute_error: 15.8438
# Epoch 61/100
# 7/7 [==============================] - 0s 8ms/step - loss: 946.2319 - mean_absolute_error: 26.0185 - val_loss: 392.9872 - val_mean_absolute_error: 18.5073
# Epoch 62/100
# 7/7 [==============================] - 0s 12ms/step - loss: 937.5335 - mean_absolute_error: 25.8375 - val_loss: 247.1758 - val_mean_absolute_error: 14.1263
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 945.7073 - mean_absolute_error: 25.9782 - val_loss: 273.4174 - val_mean_absolute_error: 14.9685
# Epoch 64/100
# 7/7 [==============================] - 0s 10ms/step - loss: 931.6207 - mean_absolute_error: 25.7684 - val_loss: 288.3851 - val_mean_absolute_error: 15.4383
# Epoch 65/100
# 7/7 [==============================] - 0s 8ms/step - loss: 921.7938 - mean_absolute_error: 25.6422 - val_loss: 248.5128 - val_mean_absolute_error: 14.1906
# Epoch 66/100
# 7/7 [==============================] - 0s 8ms/step - loss: 905.9395 - mean_absolute_error: 25.4419 - val_loss: 240.1869 - val_mean_absolute_error: 13.9289
# Epoch 67/100
# 7/7 [==============================] - 0s 8ms/step - loss: 877.7463 - mean_absolute_error: 25.0716 - val_loss: 312.1220 - val_mean_absolute_error: 16.2581
# Epoch 68/100
# 7/7 [==============================] - 0s 8ms/step - loss: 849.6525 - mean_absolute_error: 24.6060 - val_loss: 300.0386 - val_mean_absolute_error: 15.9026
# Epoch 69/100
# 7/7 [==============================] - 0s 8ms/step - loss: 814.3872 - mean_absolute_error: 24.0760 - val_loss: 232.7880 - val_mean_absolute_error: 13.7373
# Epoch 70/100
# 7/7 [==============================] - 0s 8ms/step - loss: 816.0074 - mean_absolute_error: 24.1181 - val_loss: 219.6616 - val_mean_absolute_error: 13.3014
# Epoch 71/100
# 7/7 [==============================] - 0s 8ms/step - loss: 794.6384 - mean_absolute_error: 23.7671 - val_loss: 295.6298 - val_mean_absolute_error: 15.8237
# Epoch 72/100
# 7/7 [==============================] - 0s 8ms/step - loss: 797.7477 - mean_absolute_error: 23.8136 - val_loss: 146.8771 - val_mean_absolute_error: 10.4276
# Epoch 73/100
# 7/7 [==============================] - 0s 8ms/step - loss: 776.6818 - mean_absolute_error: 23.4950 - val_loss: 986.5717 - val_mean_absolute_error: 30.6789
# Epoch 74/100
# 7/7 [==============================] - 0s 8ms/step - loss: 858.4380 - mean_absolute_error: 24.2464 - val_loss: 146.7631 - val_mean_absolute_error: 10.4449
# Epoch 75/100
# 7/7 [==============================] - 0s 9ms/step - loss: 713.7657 - mean_absolute_error: 22.6201 - val_loss: 352.0699 - val_mean_absolute_error: 17.6060
# Epoch 76/100
# 7/7 [==============================] - 0s 8ms/step - loss: 690.6514 - mean_absolute_error: 22.2002 - val_loss: 294.2911 - val_mean_absolute_error: 15.8961
# Epoch 77/100
# 7/7 [==============================] - 0s 8ms/step - loss: 635.9462 - mean_absolute_error: 21.1167 - val_loss: 200.2153 - val_mean_absolute_error: 12.7251
# Epoch 78/100
# 7/7 [==============================] - 0s 8ms/step - loss: 561.6126 - mean_absolute_error: 19.7178 - val_loss: 80.7055 - val_mean_absolute_error: 7.2755
# Epoch 79/100
# 7/7 [==============================] - 0s 10ms/step - loss: 596.6824 - mean_absolute_error: 20.5529 - val_loss: 405.0704 - val_mean_absolute_error: 19.1821
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 514.0092 - mean_absolute_error: 18.9302 - val_loss: 167.1760 - val_mean_absolute_error: 11.5370
# Epoch 81/100
# 7/7 [==============================] - 0s 10ms/step - loss: 445.2997 - mean_absolute_error: 17.5099 - val_loss: 112.4496 - val_mean_absolute_error: 9.0445
# Epoch 82/100
# 7/7 [==============================] - 0s 8ms/step - loss: 402.0401 - mean_absolute_error: 16.6289 - val_loss: 118.3358 - val_mean_absolute_error: 9.3957
# Epoch 83/100
# 7/7 [==============================] - 0s 9ms/step - loss: 365.8430 - mean_absolute_error: 15.7847 - val_loss: 111.2137 - val_mean_absolute_error: 9.0564
# Epoch 84/100
# 7/7 [==============================] - 0s 8ms/step - loss: 313.3333 - mean_absolute_error: 14.6235 - val_loss: 110.1688 - val_mean_absolute_error: 9.0289
# Epoch 85/100
# 7/7 [==============================] - 0s 9ms/step - loss: 255.6076 - mean_absolute_error: 12.9127 - val_loss: 58.4921 - val_mean_absolute_error: 6.1429
# Epoch 86/100
# 7/7 [==============================] - 0s 8ms/step - loss: 223.6008 - mean_absolute_error: 11.7541 - val_loss: 36.1404 - val_mean_absolute_error: 5.0952
# Epoch 87/100
# 7/7 [==============================] - 0s 9ms/step - loss: 212.7941 - mean_absolute_error: 11.5448 - val_loss: 36.0894 - val_mean_absolute_error: 5.1392
# Epoch 88/100
# 7/7 [==============================] - 0s 8ms/step - loss: 192.1326 - mean_absolute_error: 10.9153 - val_loss: 38.9754 - val_mean_absolute_error: 5.2752
# Epoch 89/100
# 7/7 [==============================] - 0s 8ms/step - loss: 167.1111 - mean_absolute_error: 10.6385 - val_loss: 65.9745 - val_mean_absolute_error: 6.7366
# Epoch 90/100
# 7/7 [==============================] - 0s 8ms/step - loss: 129.3091 - mean_absolute_error: 9.1432 - val_loss: 106.0995 - val_mean_absolute_error: 8.8076
# Epoch 91/100
# 7/7 [==============================] - 0s 8ms/step - loss: 123.4573 - mean_absolute_error: 8.9616 - val_loss: 48.4069 - val_mean_absolute_error: 5.8297
# Epoch 92/100
# 7/7 [==============================] - 0s 10ms/step - loss: 91.6601 - mean_absolute_error: 7.1881 - val_loss: 43.1512 - val_mean_absolute_error: 5.5704
# Epoch 93/100
# 7/7 [==============================] - 0s 8ms/step - loss: 85.8377 - mean_absolute_error: 7.0413 - val_loss: 30.6226 - val_mean_absolute_error: 4.9242
# Epoch 94/100
# 7/7 [==============================] - 0s 10ms/step - loss: 65.8480 - mean_absolute_error: 6.2048 - val_loss: 30.3405 - val_mean_absolute_error: 4.8249
# Epoch 95/100
# 7/7 [==============================] - 0s 8ms/step - loss: 61.3432 - mean_absolute_error: 5.8597 - val_loss: 30.6231 - val_mean_absolute_error: 4.8272
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 56.3616 - mean_absolute_error: 5.6383 - val_loss: 53.3331 - val_mean_absolute_error: 5.6966
# Epoch 97/100
# 7/7 [==============================] - 0s 8ms/step - loss: 59.6241 - mean_absolute_error: 6.1737 - val_loss: 50.1115 - val_mean_absolute_error: 5.4786
# Epoch 98/100
# 7/7 [==============================] - 0s 9ms/step - loss: 46.6091 - mean_absolute_error: 5.2811 - val_loss: 43.8205 - val_mean_absolute_error: 5.1570
# Epoch 99/100
# 7/7 [==============================] - 0s 9ms/step - loss: 47.4263 - mean_absolute_error: 5.4791 - val_loss: 61.2091 - val_mean_absolute_error: 6.1430
# Epoch 100/100
# 7/7 [==============================] - 0s 8ms/step - loss: 60.1133 - mean_absolute_error: 6.2606 - val_loss: 72.0730 - val_mean_absolute_error: 6.7778

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
